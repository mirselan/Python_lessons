# %% [markdown]
# #Знакомство с языком Python (семинары)
# ##Урок 11. Jupyter Notebook и несколько слов об аналитике

# %% [markdown]
# $f(x) = -12x^4*sin(cos(x)) - 18x^3+5x^2 + 10x - 30$
#
#   __1) Определить корни:__

# %%
# По условию дана функция:
# f(x) = -12x^4*sin(cos(x)) - 18x^3+5x^2 + 10x - 30

# %%
# Импорт необходимых библиотек
###################################
import sympy
from sympy.plotting import plot
from math import sqrt #, sin, cos
import math
#from scipy.optimize import fsolve

# %%
# Обозначаем "х" как символ:
x = sympy.Symbol('x')
x
# Out:
# x

# %%
# Выводим наше уровнение:
f = -12 * x ** 4 * sympy.sin(sympy.cos(x)) - 18 * x ** 3 + 5 * x ** 2 + 10 * x - 30
f
# Out:
# -12*x**4*sin(cos(x)) - 18*x**3 + 5*x**2 + 10*x - 30

# %%
# Рисуем график:
plot(f)

# %%
plot(f, xlim=(-100, 100))

# %% [markdown]
# Из графика можно сделать вывод, что у уровнения должно быть 5 корней.

# %%
# Пытаемся найти корни уровнения:
sympy.solve(f, x)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-83-cf3f7f6b53b1> in <module>
#       1 # Пытаемся найти корни уровнения:
# ----> 2 sympy.solve(f, x)
#
# /usr/local/lib/python3.8/dist-packages/sympy/solvers/solvers.py in solve(f, *symbols, **flags)
#    1095     ###########################################################################
#    1096     if bare_f:
# -> 1097         solution = _solve(f[0], *symbols, **flags)
#    1098     else:
#    1099         solution = _solve_system(f, symbols, **flags)
#
# /usr/local/lib/python3.8/dist-packages/sympy/solvers/solvers.py in _solve(f, *symbols, **flags)
#    1714
#    1715     if result is False:
# -> 1716         raise NotImplementedError('\n'.join([msg, not_impl_msg % f]))
#    1717
#    1718     if flags.get('simplify', True):
#
# NotImplementedError: multiple generators [x, sin(cos(x))]
# ...

# %% [markdown]
# Попытка найти корни уровнения завершается ошибкой.

# %%
# Пытаемся взять синус и косинус для уровнения из библиотеки 'math':
f_2 = -12 * x ** 4 * math.sin(math.cos(x)) - 18 * x ** 3 + 5 * x ** 2 + 10 * x - 30
f_2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-79-7f43c9c6f157> in <module>
# ----> 1 f_2 = -12 * x ** 4 * math.sin(math.cos(x)) - 18 * x ** 3 + 5 * x ** 2 + 10 * x - 30
#       2 f_2
#
# /usr/local/lib/python3.8/dist-packages/sympy/core/expr.py in __float__(self)
#     348         if result.is_number and result.as_real_imag()[1]:
#     349             raise TypeError("can't convert complex to float")
# --> 350         raise TypeError("can't convert expression to float")
#     351
#     352     def __complex__(self):
#
# TypeError: can't convert expression to float

# %% [markdown]
# Все опять завершается ошибкой.

# %%
# Скорее всего это неправильно, но я попробую разделить исходное уравенние на две части и посмотреть, что будет...
f_3 = -12 * x ** 4 * sympy.sin(sympy.cos(x))
f_4= - 18 * x ** 3 + 5 * x ** 2 + 10 * x - 30
f_3
# Out:
# -12*x**4*sin(cos(x))

# %%
plot(f_3)

# %%
plot(f_3, xlim=(-100, 100))

# %% [markdown]
# График первой половины уровнения практически полностью совпадает с графиком исходного уровнения. При этом пересечение графиком оси Х, т.е. корни уравнений, совпадают полностью.

# %%
# Найдем корни первой половины уровнения:
roots = sympy.solve(f_3, x)
roots
# Out:
# [0, pi/2, 3*pi/2, 2*pi - acos(pi), acos(pi)]

# %%
# Вторая часть уровнения:
f_4
# Out:
# -18*x**3 + 5*x**2 + 10*x - 30

# %%
plot(f_4, xlim=(-100, 100))

# %%
sympy.solve(f_4, x)
# Out:
# [5/54 - 565/(972*(-1/2 - sqrt(3)*I/2)*(5*sqrt(218931)/108 + 127045/5832)**(1/3)) - (-1/2 - sqrt(3)*I/2)*(5*sqrt(218931)/108 + 127045/5832)**(1/3)/3,
#  5/54 - (-1/2 + sqrt(3)*I/2)*(5*sqrt(218931)/108 + 127045/5832)**(1/3)/3 - 565/(972*(-1/2 + sqrt(3)*I/2)*(5*sqrt(218931)/108 + 127045/5832)**(1/3)),
#  -(5*sqrt(218931)/108 + 127045/5832)**(1/3)/3 - 565/(972*(5*sqrt(218931)/108 + 127045/5832)**(1/3)) + 5/54]

# %%
# Соеденим обе части уровнения и получим исходное уравнение:
f_5 = f_3 + f_4
f_5
# Out:
# -12*x**4*sin(cos(x)) - 18*x**3 + 5*x**2 + 10*x - 30

# %%
plot(f_5)

# %%
plot(f_5, xlim=(-100, 100))

# %% [markdown]
# На основании идентичности графика исходного уравнения:
# $f(x) = -12x^4*sin(cos(x)) - 18x^3+5x^2 + 10x - 30$
#
# и графика уровнения:
#
# $f(x) = -12x^4*sin(cos(x))$
#
# делаю вывод, что корни первого и второго уравнений совпадают. Т.е. корнями исходного уравнения будут являться следующие значения: $0, pi/2, 3*pi/2, 2*pi - acos(pi), acos(pi)$.

# %% [markdown]
# __2) Найти интервалы, на которых функция возрастает:__

# %% [markdown]
# Так как вершину определить не удалось, данный интервал также определить не могу.

# %% [markdown]
# __3) Найти интервалы, на которых функция убывает:__

# %% [markdown]
# Так как вершину определить не удалось, данный интервал также определить не могу.

# %% [markdown]
#   __5) Вычислить вершину:__

# %%
from sympy.calculus.util import minimum, Interval

# %%
intv = Interval(roots[2], roots[-1])
min = minimum(f, x, intv)
min
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-96-82e9aa29aeba> in <module>
# ----> 1 intv = Interval(roots[2], roots[-1])
#       2 min = minimum(f, x, intv)
#       3 min
#
# /usr/local/lib/python3.8/dist-packages/sympy/sets/sets.py in __new__(cls, start, end, left_open, right_open)
#     911         # Only allow real intervals
#     912         if fuzzy_not(fuzzy_and(i.is_extended_real for i in (start, end, end-start))):
# --> 913             raise ValueError("Non-real intervals are not supported")
#     914
#     915         # evaluate if possible
#
# ValueError: Non-real intervals are not supported

# %% [markdown]
# Вычислить вершину не получается, в чем ошибка я не понимаю...

# %% [markdown]
#    __6) Определить промежутки, на котором f > 0:__

# %% [markdown]
# f > 0 на промежутках [$-\infty, acos(pi)$], [$0, 2*pi - acos(pi)$], [$0, pi/2$], [$3*pi/2, +\infty$]

# %% [markdown]
#   __7) Определить промежутки, на котором f < 0:__

# %% [markdown]
# f < 0 от $acos(pi)$ до $2*pi - acos(pi)$ и от $pi/2$ до $3*pi/2$.
